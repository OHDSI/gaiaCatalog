# %% [markdown]
# # Expand and ETL dataframes
#
# This code takes a CSV document into a dataframe and expands out some of the list-based columns.  It also
# pulls the attribute column into a separate dataframe and expands it externally.  Both are then mapped to
# RDF via RML files in the templates directory.  The results are aligned RDF, on a shared subject IRI, which
# can be used in a triplestore or property graph environment.
#
# Notes:
# 1) Defining a unique id, even if local to the file, for each row/record is useful

# %%
# import sys
# sys.path.append('./')

# %%
# Imports and definitions
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)  ## remove pandas future warning

import pandas as pd
import morph_kgc
import json
from shapely import wkt
import geopandas as gpd
from hashlib import sha256
# from  src import jbutils
import pyoxigraph
import io
from pygraphml import GraphMLParser
from pygraphml import Graph as GraphML
from hashlib import sha256
import networkx as nx
from ipysigma import Sigma

# %% [markdown]
# ## Defs

# %%
# String to sha256 and return 12 digits
def hash_text(text):
    return sha256(text.encode()).hexdigest()[:12]

# %%
# Split string to list
def split_string_to_list(cell_value):
    return cell_value.split('|')

# %%
def rmlmapping(df, template):
    data_dict = {"variable1": df}

    config = f"""
        [DataSource]
        mappings=./RML/{template}
        output_format=nt
        number_of_processes=1
    """

    g_rdflib = morph_kgc.materialize(config, data_dict)

    # Ensure we get a text N-Triples serialization
    nt = g_rdflib.serialize(format="nt")
    if isinstance(nt, bytes):  # depending on rdflib version
        nt = nt.decode("utf-8")
    return nt

# %% [markdown]
# ## Read in the data
# Also build out a custom ID for me at this time.

# %%
df = pd.read_csv('./input/GAIA_metadata.csv')  # alt: GDSC_metadata.csv

# %%
# Add in a unique ID column based on a hash of the title 
# A quick inspection shows this to be unique, however, it might not always be so some work here is needed
df['hashid'] = df['dct_title'].apply(hash_text)
df.insert(0, 'hashid', df.pop('hashid'))

# %%
df
# Out:
#          hashid                                   dcat_downloadURL  \
# 0  096cbb634605  file:///data/global_pm25_concentration_1998_20...
# 1  408b8a13ef6a  https://svi.cdc.gov/Documents/Data/2018/db/sta...
# 2  7b7434c73442  https://svi.cdc.gov/Documents/Data/2018/db/sta...
#
#              dct_issued        dct_type gdsc_label  \
# 0  2021-04-06T00:00:00Z  Vector Dataset       name
# 1  2020-10-22T00:00:00Z  Vector Dataset   location
# 2  2020-10-22T00:00:00Z  Vector Dataset   location
#
#                   prov_wasGeneratedBy  \
# 0  GDSC automation (see Process Step)
# 1  GDSC automation (see Process Step)
# 2  GDSC automation (see Process Step)
#
#                                          prov_action  dcat_qualifiedRelation  \
# 0  #########\n# GDSC ETL is performed in two step...                     NaN
# 1  #########\n# GDSC ETL is performed in two step...                     NaN
# 2  #########\n# GDSC ETL is performed in two step...                     NaN
#
#     dct_coverage                                    id  ... gdsc_up  \
# 0         Global  1257a4ac-a6fc-4326-9902-affba5d25ff7  ...    True
# 1  United States  58676ca6-9b24-4212-84e9-a54edab321df  ...    True
# 2  Massachusetts  d2dd828d-bae3-47d9-999e-3aa392059b52  ...    True
#
#                                       dct_identifier  \
# 0                  https://doi.org/10.7927/rja8-8h89
# 1  https://www.atsdr.cdc.gov/placeandhealth/svi/d...
# 2  https://www.atsdr.cdc.gov/placeandhealth/svi/d...
#
#                                         gdsc_sponsor  \
# 0  TuftsCTSI;https://www.tuftsctsi.org/|IDSC;http...
# 1  TuftsCTSI;https://www.tuftsctsi.org/|IDSC;http...
# 2  TuftsCTSI;https://www.tuftsctsi.org/|IDSC;http...
#
#                                          dct_license  \
# 0  This work is licensed under the Creative Commo...
# 1                                                NaN
# 2                                                NaN
#
#                         gdsc_tablename  \
# 0  global_pm25_concentration_1998_2016
# 1                   us_2018_svi_county
# 2                    ma_2018_svi_tract
#
#                                      dct_description dct_conformsTo  \
# 0  The Annual PM2.5 Concentrations for Countries ...      EPSG:4326
# 1  Social vulnerability refers to the potential n...      EPSG:4326
# 2  Social vulnerability refers to the potential n...      EPSG:4326
#
#                                      gdsc_attributes            _version_  \
# 0  urbid;Code of the urban extent polygons (not u...  1812488469684944896
# 1  area_sqmi;Tract area in square miles;Census AC...  1812488469786656768
# 2  area_sqmi;Tract area in square miles;Census AC...  1812488470020489216
#
#   gdsc_tileUrl
# 0          NaN
# 1          NaN
# 2          NaN
#
# [3 rows x 45 columns]

# %% [markdown]
# ## Attributes dataframe
# The attribute column has a lot of structures, lets pull it out and represent that structure in a new dataframe we can pass to a dedicated template.  We only need to keep track of the top level data graph subject IRI from our hash.

# %%
selected_columns = ['hashid', 'gdsc_attributes']
adf = df[selected_columns]#%%
adf = adf.dropna(subset=['gdsc_attributes'])
adf['gdsc_attributes'] = adf['gdsc_attributes'].apply(split_string_to_list)
adf_exploded = adf.explode('gdsc_attributes')

# %%
var_attributes = [
    'var_name',
    'var_desc',
    'var_source',
    'var_dtype',
    'var_units_text',
    'var_units_concept_id',
    'var_start_date',
    'var_end_date',
    'var_concept_id',
    'var_gaia_id'
]

# %%
for var_attr in var_attributes: adf_exploded[var_attr] = None

# %%
def assign_from_list(row):
    attributes = row['gdsc_attributes'].split(';')
    
    for i,var_attr in enumerate(var_attributes):
        row[var_attr] = attributes[i] if len(attributes) > i else ""
        
    return row

# %%
# Legacy
def assign_from_list(row):
    attributes = row['gdsc_attributes'].split(';')

    # Assign the values to the respective columns
    row['var_name'] = attributes[0] if len(attributes) > 0 else ""
    row['var_desc'] = attributes[1] if len(attributes) > 1 else ""
    row['var_source'] = attributes[2] if len(attributes) > 2 else ""
    row['var_dtype'] = attributes[3] if len(attributes) > 3 else ""
    row['var_units_text'] = attributes[4] if len(attributes) > 4 else ""
    row['var_units_concept_id'] = attributes[5] if len(attributes) > 5 else ""
    row['var_start_date'] = attributes[6] if len(attributes) > 6 else ""
    row['var_end_date'] = attributes[7] if len(attributes) > 7 else ""

    return row

# %%
adf_exploded = adf_exploded.apply(assign_from_list, axis=1)

# %%
adf_exploded
# Out:
#           hashid                                    gdsc_attributes  \
# 0   096cbb634605  urbid;Code of the urban extent polygons (not u...
# 0   096cbb634605  stndrdname;"Name of the Urban Extent, caps and...
# 0   096cbb634605  name;"Name of the Urban Extent. If the urban e...
# 0   096cbb634605  isourbid;Unique code of the urban extent polyg...
# 0   096cbb634605  sqkm;Area of the urban extent polygon;SEDAC;do...
# ..           ...                                                ...
# 2   7b7434c73442  spl_themes;Sum of series themes;Census ACS;flo...
# 2   7b7434c73442  st;State FIPS code;Census ACS;varchar;;;;;2052...
# 2   7b7434c73442  st_abbr;State abbreviation;Census ACS;varchar;...
# 2   7b7434c73442  state;State name;Census ACS;varchar;;;;;205249...
# 2   7b7434c73442  stcnty;State and county FIPS code as STATE(2)C...
#
#       var_name                                           var_desc  var_source  \
# 0        urbid     Code of the urban extent polygons (not unique)       SEDAC
# 0   stndrdname  "Name of the Urban Extent, caps and concatenat...       SEDAC
# 0         name  "Name of the Urban Extent. If the urban extent...       SEDAC
# 0     isourbid  Unique code of the urban extent polygons. It i...       SEDAC
# 0         sqkm                   Area of the urban extent polygon       SEDAC
# ..         ...                                                ...         ...
# 2   spl_themes                               Sum of series themes  Census ACS
# 2           st                                    State FIPS code  Census ACS
# 2      st_abbr                                 State abbreviation  Census ACS
# 2        state                                         State name  Census ACS
# 2       stcnty    State and county FIPS code as STATE(2)COUNTY(3)  Census ACS
#
#    var_dtype     var_units_text var_units_concept_id var_start_date  \
# 0    integer
# 0     string
# 0     string
# 0     string
# 0     double  square kilometers
# ..       ...                ...                  ...            ...
# 2     float8          svi index                          2018-01-01
# 2    varchar
# 2    varchar
# 2    varchar
# 2    varchar
#
#    var_end_date var_concept_id var_gaia_id
# 0                         None        None
# 0                         None        None
# 0                         None        None
# 0                         None        None
# 0                         None        None
# ..          ...            ...         ...
# 2    2018-12-31           None        None
# 2                         None        None
# 2                         None        None
# 2                         None        None
# 2                         None        None
#
# [276 rows x 12 columns]

# %% [markdown]
# ## Process the dataframes
#
# Here process the dataframes with the associated mapping files

# %%
ats = rmlmapping(adf_exploded,  "attribute_template.ttl")
ts = rmlmapping(df, "gdsc_template.ttl")
# Out:
# INFO | 2025-11-20 10:49:20,884 | 13 mapping rules retrieved.
# INFO | 2025-11-20 10:49:20,893 | Mapping partition with 13 groups generated.
# INFO | 2025-11-20 10:49:20,895 | Maximum number of rules within mapping group: 1.
# INFO | 2025-11-20 10:49:20,895 | Mappings processed in 0.518 seconds.
# INFO | 2025-11-20 10:49:21,481 | Number of triples generated in total: 2954.
# INFO | 2025-11-20 10:49:21,928 | 9 mapping rules retrieved.
# INFO | 2025-11-20 10:49:21,934 | Mapping partition with 9 groups generated.
# INFO | 2025-11-20 10:49:21,935 | Maximum number of rules within mapping group: 1.
# INFO | 2025-11-20 10:49:21,935 | Mappings processed in 0.389 seconds.
# INFO | 2025-11-20 10:49:22,525 | Number of triples generated in total: 25.

# %%
print(ats)
# Out:
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_mobile> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_age17> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_groupq> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_unemp> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/spl_themes> <https://schema.org/name> "spl_themes" .
# <http://ohdsi_gis.org/id/408b8a13ef6a> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_nohsdp> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_age65> <https://schema.org/name> "mp_age65" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_hu> <https://schema.org/unitsText> "housing units" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_limeng> <https://schema.org/unitsText> "percentile" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_mobile> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_uninsur> <https://schema.org/description> "Adjunct variable - Percentage uninsured in the total civilian non-institutionalized population estimate, 2014-2018 ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_sngpnt> <https://schema.org/name> "epl_sngpnt" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_age65> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_age65> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_crowd> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/spl_theme3> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_pov> <https://schema.org/additionalType> "boolean" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_age65> <https://schema.org/additionalType> "float8" .
# <http://ohdsi_gis.org/id/408b8a13ef6a> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_crowd> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_groupq> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_munit> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_theme2> <https://schema.org/gaiaId> "None" .
# <http://ohdsi_gis.org/id/408b8a13ef6a> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_munit> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_groupq> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_disabl> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_unemp> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_pov> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_limeng> <https://schema.org/name> "e_limeng" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_daypop> <https://schema.org/description> "Adjunct variable - Estimated daytime population, LandScan 2018" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_groupq> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_age65> <https://schema.org/unitsText> "persons" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_age17> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_theme1> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_limeng> <https://schema.org/name> "epl_limeng" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_pci> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_hh> <https://schema.org/endDate> "2018-12-31" .
# <http://ohdsi_gis.org/id/096cbb634605> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2011> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_age65> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_sngpnt> <https://schema.org/unitsText> "percentile" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/area_sqmi> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_disabl> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/rpl_themes> <https://schema.org/endDate> "2018-12-31" .
# <http://ohdsi_gis.org/id/408b8a13ef6a> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_pov> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_limeng> <https://schema.org/description> "Percentage of persons (age 5+) who speak English less than well estimate, 2014-2018 ACS" .
# <http://ohdsi_gis.org/id/408b8a13ef6a> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_age17> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_age17> <https://schema.org/description> "Percentage of persons aged 17 and younger estimate MOE, 2014-2018 ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_unemp> <https://schema.org/name> "m_unemp" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2011> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2005> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_limeng> <https://schema.org/additionalType> "int4" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_nohsdp> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/location> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_daypop> <https://schema.org/name> "e_daypop" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_crowd> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/rpl_theme2> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_sngpnt> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_age65> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_sngpnt> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_1998> <https://schema.org/additionalType> "double" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_unemp> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/rpl_theme2> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_crowd> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_nohsdp> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_mobile> <https://schema.org/description> "Mobile homes estimate MOE, 2014-2018 ACS" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_nohsdp> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_nohsdp> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_pov> <https://schema.org/unitsText> "percentile" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_munit> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_minrty> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_minrty> <https://schema.org/name> "ep_minrty" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_minrty> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_noveh> <https://schema.org/name> "epl_noveh" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/area_sqmi> <https://schema.org/description> "Tract area in square miles" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/rpl_theme3> <https://schema.org/name> "rpl_theme3" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_hu> <https://schema.org/name> "e_hu" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_age17> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_sngpnt> <https://schema.org/description> "Single parent household with children under 18 estimate MOE, 2014-2018 ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_unemp> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_noveh> <https://schema.org/additionalType> "float8" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_disabl> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_pov> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_noveh> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/spl_theme2> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_age17> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_pov> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_limeng> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_sngpnt> <https://schema.org/description> "Percentile percentage of single parent households with children under 18 estimate" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/iso3> <https://schema.org/additionalType> "string" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_sngpnt> <https://schema.org/name> "e_sngpnt" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/spl_theme3> .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/urbid> <https://schema.org/measurementMethod> "SEDAC" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_pov> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_munit> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_age17> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2008> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/continent> <https://schema.org/measurementMethod> "SEDAC" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2013> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/st_abbr> <https://schema.org/additionalType> "varchar" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_mobile> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_groupq> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_pci> <https://schema.org/additionalType> "int4" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_munit> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_sngpnt> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_theme1> <https://schema.org/additionalType> "int4" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_disabl> <https://schema.org/additionalType> "int4" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_age17> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_limeng> <https://schema.org/endDate> "2018-12-31" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_age65> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_crowd> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/rpl_theme3> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_disabl> <https://schema.org/description> "Percentile percentage of civilian non-institutionalized population with a disability estimate" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_totpop> <https://schema.org/unitsText> "persons" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/st_abbr> <https://schema.org/name> "st_abbr" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_age17> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_noveh> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/name> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_minrty> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_pci> <https://schema.org/additionalType> "int4" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_theme4> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/rpl_theme2> <https://schema.org/description> "Percentile ranking for Household Composition theme summary" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_minrty> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_minrty> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_sngpnt> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/st_abbr> <https://schema.org/conceptId> "None" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_nohsdp> .
# <http://ohdsi_gis.org/id/096cbb634605> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_1999> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_nohsdp> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/spl_theme3> <https://schema.org/unitsText> "svi index" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/rpl_theme2> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2008> <https://schema.org/unitsConceptId> "32964" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/spl_theme2> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/name> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2012> <https://schema.org/additionalType> "double" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_mobile> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2016> <https://schema.org/unitsText> "micrograms/cubic meter" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_pov> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_mobile> <https://schema.org/description> "Percentage of mobile homes estimate MOE" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_munit> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_pci> <https://schema.org/description> "Per capita income estimate, 2014-2018 ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_sngpnt> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_crowd> <https://schema.org/description> "At household level (occupied housing units), more people than rooms estimate MOE, 2014-2018 ACS" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_unemp> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_nohsdp> <https://schema.org/additionalType> "int4" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2016> <https://schema.org/endDate> "2016-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/rpl_theme3> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_noveh> <https://schema.org/name> "f_noveh" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_theme3> <https://schema.org/description> "Sum of flags for Minority Status/Languag e theme" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_age65> <https://schema.org/endDate> "2018-12-31" .
# <http://ohdsi_gis.org/id/096cbb634605> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/096cbb634605/countryeng> .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2006> <https://schema.org/measurementMethod> "SEDAC" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_crowd> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/rpl_theme3> <https://schema.org/startDate> "2018-01-01" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_groupq> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_groupq> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_unemp> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/spl_theme3> <https://schema.org/description> "Sum of series for Minority Status/Languag e theme" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_unemp> <https://schema.org/unitsText> "persons" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2011> <https://schema.org/startDate> "2011-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_noveh> <https://schema.org/name> "ep_noveh" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_noveh> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_age17> <https://schema.org/additionalType> "float8" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_age65> .
# <http://ohdsi_gis.org/id/408b8a13ef6a> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_theme4> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_hh> <https://schema.org/description> "Households estimate MOE, 2014-2018 ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/area_sqmi> <https://schema.org/name> "area_sqmi" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_munit> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/fips> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/unsdcode> <https://schema.org/description> "UNSD country numerical code" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2002> <https://schema.org/measurementMethod> "SEDAC" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_uninsur> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_munit> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_hu> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_minrty> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_munit> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_nohsdp> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_groupq> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_munit> <https://schema.org/name> "m_munit" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_limeng> <https://schema.org/additionalType> "int4" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_sngpnt> <https://schema.org/additionalType> "int4" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_hh> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_age65> <https://schema.org/name> "e_age65" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_mobile> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_noveh> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_sngpnt> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_sngpnt> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_munit> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/rpl_theme1> .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/name> <https://schema.org/additionalType> "string" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_nohsdp> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_uninsur> <https://schema.org/unitsText> "percentage" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_age17> <https://schema.org/unitsText> "percentage" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/rpl_theme4> <https://schema.org/description> "Percentile ranking for Housing Type/Transportation theme" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/spl_theme3> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2014> <https://schema.org/unitsText> "micrograms/cubic meter" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_minrty> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_pci> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_age65> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/spl_themes> <https://schema.org/description> "Sum of series themes" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_minrty> <https://schema.org/name> "f_minrty" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_pov> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_pci> <https://schema.org/name> "mp_pci" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_groupq> <https://schema.org/description> "Persons in group quarters estimate MOE, 2014-2018 ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_minrty> <https://schema.org/additionalType> "int4" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_unemp> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/rpl_theme1> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_age65> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_noveh> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_groupq> <https://schema.org/startDate> "2018-01-01" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_totpop> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_nohsdp> <https://schema.org/description> "Percentage of persons with no high school diploma (25+) estimate MOE" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_pov> <https://schema.org/unitsText> "persons" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_crowd> <https://schema.org/description> "Flag - the percentage of crowded households is in the 90th percentile (1 = yes, 0 = no)" .
# <http://ohdsi_gis.org/id/096cbb634605> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/Dataset> .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2002> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_noveh> <https://schema.org/description> "Households with no vehicle available estimate, 2014-2018 ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/spl_theme4> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_noveh> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_munit> <https://schema.org/unitsText> "percentile" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_sngpnt> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_groupq> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_pov> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_age65> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_age65> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_sngpnt> <https://schema.org/unitsText> "percentage" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_theme2> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_pci> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/fips> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_sngpnt> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_groupq> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_groupq> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_mobile> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_hu> <https://schema.org/additionalType> "int4" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/rpl_theme1> <https://schema.org/name> "rpl_theme1" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_pov> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_theme3> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_nohsdp> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_age65> <https://schema.org/description> "Percentage of persons aged 65 and older estimate, 2014-2018 ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_age17> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_age17> <https://schema.org/description> "Flag - the percentage of persons aged 17 and younger is in the 90th percentile (1 = yes, 0 = no)" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_sngpnt> <https://schema.org/unitsText> "percentage" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/spl_theme3> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_daypop> <https://schema.org/additionalType> "int4" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_totpop> <https://schema.org/description> "Population estimate MOE, 2014-2018 ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_limeng> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/rpl_theme2> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2004> <https://schema.org/endDate> "2004-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_crowd> <https://schema.org/description> "Percentile percentage households with more people than rooms estimate" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_nohsdp> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_pci> <https://schema.org/name> "epl_pci" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_sngpnt> <https://schema.org/name> "ep_sngpnt" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_age65> <https://schema.org/endDate> "2018-12-31" .
# <http://ohdsi_gis.org/id/408b8a13ef6a> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/location> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_theme1> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_total> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_minrty> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2001> <https://schema.org/description> "PM2.5 Exposure for named urban areas from GRUMPv1: Urban Extent Polygons, Revision 02, from 2001. It is measured in micrograms per cubic meter, and is the average annual concentration of PM2.5 to which the typical citizen of each urban area is exposed. Blanks (-9999) represent missing data." .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_groupq> <https://schema.org/name> "epl_groupq" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2008> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2010> <https://schema.org/measurementMethod> "SEDAC" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_disabl> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_munit> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2013> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_noveh> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_unemp> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_pci> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_pov> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_age17> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_nohsdp> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_nohsdp> <https://schema.org/description> "Percentage of persons with no high school diploma (age 25+) estimate" .
# <http://ohdsi_gis.org/id/408b8a13ef6a> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/rpl_theme4> .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2000> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2016> <https://schema.org/name> "avpmu_2016" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/rpl_themes> <https://schema.org/description> "Overall percentile ranking" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/rpl_theme3> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_age17> <https://schema.org/description> "Persons aged 17 and younger estimate MOE, 2014-2018 ACS" .
# <http://ohdsi_gis.org/id/408b8a13ef6a> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_hh> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_disabl> <https://schema.org/additionalType> "boolean" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_unemp> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_theme3> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_uninsur> <https://schema.org/description> "Adjunct variable - Percentage uninsured in the total civilian non-institutionalized population estimate, 2014-2018 ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_munit> <https://schema.org/name> "e_munit" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_minrty> <https://schema.org/description> "Percentage minority (all persons except white, non-Hispanic) estimate MOE, 2014-2018 ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_mobile> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_age17> <https://schema.org/name> "m_age17" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2016> <https://schema.org/description> "PM2.5 Exposure for named urban areas from GRUMPv1: Urban Extent Polygons, Revision 02, from 2016. It is measured in micrograms per cubic meter, and is the average annual concentration of PM2.5 to which the typical citizen of each urban area is exposed. Blanks (-9999) represent missing data." .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_age65> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/spl_theme4> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_pci> <https://schema.org/additionalType> "int4" .
# <http://ohdsi_gis.org/id/408b8a13ef6a> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_age17> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_disabl> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_limeng> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/fips> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_totpop> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_totpop> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/spl_theme3> <https://schema.org/name> "spl_theme3" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_hu> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_nohsdp> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/rpl_theme4> <https://schema.org/startDate> "2018-01-01" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_totpop> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_pci> <https://schema.org/name> "m_pci" .
# <http://ohdsi_gis.org/id/408b8a13ef6a> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_disabl> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_pci> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_pci> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_theme1> <https://schema.org/additionalType> "int4" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_mobile> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_noveh> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_age65> <https://schema.org/gaiaId> "None" .
# <http://ohdsi_gis.org/id/408b8a13ef6a> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_limeng> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_noveh> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/spl_theme2> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_uninsur> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_pov> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_uninsur> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_nohsdp> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_hu> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_1999> <https://schema.org/startDate> "1999-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_minrty> <https://schema.org/description> "Percentage minority (all persons except white, non-Hispanic) estimate, 2014-2018 ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_pov> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_groupq> <https://schema.org/additionalType> "int4" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_noveh> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/rpl_theme1> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_munit> <https://schema.org/unitsText> "structures" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_limeng> <https://schema.org/name> "mp_limeng" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_pov> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_pov> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/fips> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_age17> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_age65> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_nohsdp> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_sngpnt> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_minrty> <https://schema.org/unitsText> "percentile" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_disabl> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_theme1> <https://schema.org/name> "f_theme1" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_groupq> <https://schema.org/name> "ep_groupq" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_age17> <https://schema.org/name> "epl_age17" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/location> <https://schema.org/name> "location" .
# <http://ohdsi_gis.org/id/408b8a13ef6a> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_theme3> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_munit> <https://schema.org/name> "epl_munit" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_uninsur> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_age17> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/rpl_theme1> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_unemp> <https://schema.org/unitsText> "percentage" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_pov> <https://schema.org/unitsText> "percentage" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_daypop> <https://schema.org/name> "e_daypop" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_pov> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_pci> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_pov> <https://schema.org/name> "f_pov" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_limeng> <https://schema.org/additionalType> "boolean" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_theme2> <https://schema.org/description> "Sum of flags for Household Composition theme" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_age65> <https://schema.org/description> "Persons aged 65 and older estimate MOE, 2014-2018 ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_limeng> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_theme4> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_limeng> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_pov> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_uninsur> <https://schema.org/name> "e_uninsur" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_minrty> .
# <http://ohdsi_gis.org/id/096cbb634605> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2009> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_sngpnt> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2011> <https://schema.org/unitsConceptId> "32964" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_age65> <https://schema.org/additionalType> "int4" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2008> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_munit> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_pov> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2013> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/stcnty> <https://schema.org/description> "State and county FIPS code as STATE(2)COUNTY(3)" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_limeng> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_sngpnt> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_minrty> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_age17> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_sngpnt> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_munit> <https://schema.org/description> "Housing in structures with 10 or more units estimate MOE, 2014- 2018 ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_totpop> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_noveh> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/state> <https://schema.org/description> "State name" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_age17> <https://schema.org/conceptId> "None" .
# <http://ohdsi_gis.org/id/096cbb634605> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/096cbb634605/isourbid> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_theme4> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_unemp> <https://schema.org/description> "Unemployment Rate estimate" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_age65> <https://schema.org/description> "Percentile percentage of persons aged 65 and older estimate" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_limeng> <https://schema.org/name> "epl_limeng" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_unemp> <https://schema.org/name> "ep_unemp" .
# <http://ohdsi_gis.org/id/408b8a13ef6a> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_pov> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_sngpnt> <https://schema.org/name> "mp_sngpnt" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2014> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_unemp> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/location> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/st> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_total> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_minrty> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_1999> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_pov> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_noveh> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_disabl> <https://schema.org/measurementMethod> "Census ACS" .
# ...
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_pci> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_theme3> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_age65> <https://schema.org/description> "Percentage of persons aged 65 and older estimate MOE, 2014-2018 ACS" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/isourbid> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <http://ohdsi_gis.org/id/408b8a13ef6a> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_groupq> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_minrty> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/rpl_theme3> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_pci> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/st_abbr> <https://schema.org/description> "State abbreviation" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/rpl_theme4> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_disabl> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/fips> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_limeng> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_uninsur> <https://schema.org/conceptId> "None" .
# <http://ohdsi_gis.org/id/408b8a13ef6a> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_limeng> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_groupq> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/spl_theme2> <https://schema.org/description> "Sum of series for Household Composition theme" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_hu> <https://schema.org/description> "Housing units estimate, 2014-2018 ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_sngpnt> <https://schema.org/unitsText> "households" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/rpl_theme1> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/stndrdname> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_unemp> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2008> <https://schema.org/endDate> "2008-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_totpop> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_totpop> <https://schema.org/additionalType> "int4" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/fips> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2001> <https://schema.org/unitsConceptId> "32964" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_minrty> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_munit> <https://schema.org/additionalType> "float8" .
# <http://ohdsi_gis.org/id/408b8a13ef6a> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/rpl_theme1> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_minrty> <https://schema.org/name> "epl_minrty" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_theme1> .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2003> <https://schema.org/measurementMethod> "SEDAC" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_pov> <https://schema.org/name> "f_pov" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_sngpnt> <https://schema.org/name> "f_sngpnt" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_disabl> <https://schema.org/description> "Flag - the percentage of persons with a disability is in the 90th percentile (1 = yes, 0 = no)" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/spl_themes> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_theme1> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_age65> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_crowd> <https://schema.org/name> "f_crowd" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/county> <https://schema.org/additionalType> "varchar" .
# <http://ohdsi_gis.org/id/096cbb634605> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2003> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_unemp> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_age65> <https://schema.org/unitsText> "percentile" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_uninsur> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_age65> <https://schema.org/unitsText> "percentage" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_sngpnt> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_crowd> <https://schema.org/unitsText> "percentage" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_unemp> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/spl_theme2> <https://schema.org/unitsText> "svi index" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/spl_theme2> <https://schema.org/name> "spl_theme2" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_groupq> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_nohsdp> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_mobile> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_crowd> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/iso3> <https://schema.org/description> "3 letter country code" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_mobile> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_crowd> <https://schema.org/gaiaId> "None" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_unemp> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_groupq> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_hh> <https://schema.org/unitsText> "households" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_pci> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_age65> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_disabl> <https://schema.org/additionalType> "int4" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_munit> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_mobile> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_nohsdp> <https://schema.org/unitsText> "percentage" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_pci> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_pov> <https://schema.org/description> "Flag - the percentage of persons in poverty is in the 90th percentile (1 = yes, 0 = no)" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_minrty> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_nohsdp> <https://schema.org/unitsText> "percentage" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_minrty> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_munit> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_mobile> <https://schema.org/name> "mp_mobile" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2005> <https://schema.org/gaiaId> "None" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_munit> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_pov> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_age65> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_age17> <https://schema.org/unitsText> "percentage" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_pci> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_pci> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/rpl_theme2> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_pov> <https://schema.org/name> "m_pov" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2003> <https://schema.org/endDate> "2003-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_noveh> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2012> <https://schema.org/unitsText> "micrograms/cubic meter" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/epl_age17> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_munit> <https://schema.org/unitsText> "structures" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_pov> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_age65> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_age65> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/ep_mobile> <https://schema.org/unitsText> "percentage" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_age17> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <https://schema.org/PropertyValue> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/spl_theme1> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_crowd> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_theme2> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_totpop> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_sngpnt> <https://schema.org/gaiaId> "None" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_disabl> .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_limeng> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/m_limeng> <https://schema.org/unitsText> "persons" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_pov> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_pov> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/mp_mobile> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/mp_crowd> <https://schema.org/description> "Percentage of occupied housing units with more people than rooms estimate MOE" .
# <http://ohdsi_gis.org/id/096cbb634605> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/096cbb634605/unsdcode> .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/stndrdname> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_age65> <https://schema.org/startDate> "2018-01-01" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/sqkm> <https://schema.org/description> "Area of the urban extent polygon" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_limeng> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_totpop> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/f_age17> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_sngpnt> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_nohsdp> <https://schema.org/description> "Persons (age 25+) with no high school diploma estimate, 2014-2018 ACS" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_pov> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_crowd> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/m_uninsur> <https://schema.org/additionalType> "int4" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/rpl_theme3> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_crowd> <https://schema.org/description> "Flag - the percentage of crowded households is in the 90th percentile (1 = yes, 0 = no)" .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_pov> .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/ep_noveh> <https://schema.org/gaiaId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_nohsdp> <https://schema.org/endDate> "2018-12-31" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_age17> <https://schema.org/measurementMethod> "Census ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_groupq> <https://schema.org/description> "Flag - the percentage of persons in institutionalize d group quarters is in the 90th percentile (1 = yes, 0 = no)" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/e_age65> <https://schema.org/conceptId> "None" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_minrty> <https://schema.org/additionalType> "float8" .
# <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2000> <https://schema.org/unitsConceptId> "32964" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/e_hu> <https://schema.org/description> "Housing units estimate, 2014-2018 ACS" .
# <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/f_groupq> <https://schema.org/name> "f_groupq" .
# <https://ohdsi_gis.org/.well-known/genid/408b8a13ef6a/epl_noveh> <https://schema.org/description> "Percentile percentage households with no vehicle available estimate" .
# <http://ohdsi_gis.org/id/096cbb634605> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/096cbb634605/avpmu_2012> .
# <http://ohdsi_gis.org/id/7b7434c73442> <https://schema.org/variableMeasured> <https://ohdsi_gis.org/.well-known/genid/7b7434c73442/rpl_theme4> .

# %%
# viz the graphs for development inspection if needed
# not must serialize to JSON-LD for this
# tsld = json.loads(ts)
# jbutils.show_graph(tsld)

# %% [markdown]
# # END of data ETL
#
# At this point the ETL is done, what follows is loading and queryign the data.  This should be moved elsewhere
# to maintain separation of activities.  I.e., separate data workflows from data use and analysis.

# %% [markdown]
# ## Set up the triplestore and load the results

# %%
triplestore = pyoxigraph.Store()
mime_type = "application/n-triples"   # application/n-triples or application/n-quads if you are loading those from data raw
triplestore.bulk_load(io.StringIO(ts), mime_type, base_iri=None, to_graph=None)
triplestore.bulk_load(io.StringIO(ats), mime_type, base_iri=None, to_graph=None)

# %%
qtypetype = """	PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <https://schema.org/>

SELECT DISTINCT ?source ?type ?target ?sType ?tType ?name
WHERE {
    # ?source a ?sType .
    # ?target a ?tType .
    # ?target schema:name ?name .
    # ?source ?type ?target .
}
"""

q2 = list(triplestore.query(qtypetype))

# %%
dfq = pd.DataFrame(q2)
dfq.rename(columns={0: 'source', 1: 'type', 2:  'target', 3: 'sType', 4: 'tType', 5 : "name"}, inplace=True)

# %%
dfq
# Out:
#                                      source  \
# 0    <http://ohdsi_gis.org/id/7b7434c73442>
# 1    <http://ohdsi_gis.org/id/7b7434c73442>
# 2    <http://ohdsi_gis.org/id/7b7434c73442>
# 3    <http://ohdsi_gis.org/id/7b7434c73442>
# 4    <http://ohdsi_gis.org/id/7b7434c73442>
# ..                                      ...
# 274  <http://ohdsi_gis.org/id/096cbb634605>
# 275  <http://ohdsi_gis.org/id/096cbb634605>
# 276  <http://ohdsi_gis.org/id/096cbb634605>
# 277  <http://ohdsi_gis.org/id/096cbb634605>
# 278  <http://ohdsi_gis.org/id/096cbb634605>
#
#                                       type  \
# 0    <https://schema.org/variableMeasured>
# 1    <https://schema.org/variableMeasured>
# 2    <https://schema.org/variableMeasured>
# 3    <https://schema.org/variableMeasured>
# 4    <https://schema.org/variableMeasured>
# ..                                     ...
# 274  <https://schema.org/variableMeasured>
# 275  <https://schema.org/variableMeasured>
# 276  <https://schema.org/variableMeasured>
# 277  <https://schema.org/variableMeasured>
# 278   <https://schema.org/spatialCoverage>
#
#                                                 target  \
# 0    <https://ohdsi_gis.org/.well-known/genid/7b743...
# 1    <https://ohdsi_gis.org/.well-known/genid/7b743...
# 2    <https://ohdsi_gis.org/.well-known/genid/7b743...
# 3    <https://ohdsi_gis.org/.well-known/genid/7b743...
# 4    <https://ohdsi_gis.org/.well-known/genid/7b743...
# ..                                                 ...
# 274  <https://ohdsi_gis.org/.well-known/genid/096cb...
# 275  <https://ohdsi_gis.org/.well-known/genid/096cb...
# 276  <https://ohdsi_gis.org/.well-known/genid/096cb...
# 277  <https://ohdsi_gis.org/.well-known/genid/096cb...
# 278  <https://ohdsi_gis.org/.well-known/genid/096cb...
#
#                             sType                               tType  \
# 0    <https://schema.org/Dataset>  <https://schema.org/PropertyValue>
# 1    <https://schema.org/Dataset>  <https://schema.org/PropertyValue>
# 2    <https://schema.org/Dataset>  <https://schema.org/PropertyValue>
# 3    <https://schema.org/Dataset>  <https://schema.org/PropertyValue>
# 4    <https://schema.org/Dataset>  <https://schema.org/PropertyValue>
# ..                            ...                                 ...
# 274  <https://schema.org/Dataset>  <https://schema.org/PropertyValue>
# 275  <https://schema.org/Dataset>  <https://schema.org/PropertyValue>
# 276  <https://schema.org/Dataset>  <https://schema.org/PropertyValue>
# 277  <https://schema.org/Dataset>  <https://schema.org/PropertyValue>
# 278  <https://schema.org/Dataset>          <https://schema.org/Place>
#
#                                                   name
# 0                                            "e_noveh"
# 1                                           "mp_age65"
# 2                                           "f_groupq"
# 3                                             "stcnty"
# 4                                              "f_pov"
# ..                                                 ...
# 274                                       "avpmu_2002"
# 275                                       "avpmu_2004"
# 276                                       "avpmu_2009"
# 277                                       "avpmu_2003"
# 278  "Global"^^<http://www.w3.org/2000/01/rdf-schem...
#
# [279 rows x 6 columns]

# %%
#  yeah, I get it...   don't iterate rows...  PR's welcome for this, being bad is too easy!  
# for index, row in nodes.iterrows():
#    g.add_node(row['Id'])
g = GraphML()
g.directed = False

for index, row in dfq.iterrows():
    n1 = g.add_node(row['source'])
    n1['type'] = row['sType']

    n2 = g.add_node(row['name'])
    n2['type'] = row['tType']

    e1 = g.add_edge(n1, n2)
    e1['type'] = row['type']


fname = "./output/testGraphML_hashed.graphml"
parser = GraphMLParser()
parser.write(g, fname)

# %%
g = nx.read_graphml("./output/testGraphML_hashed.graphml")

# %%
Sigma(
    g,
    node_size=g.degree,
    default_edge_type='curve',
    node_border_color_from='node',
    node_metrics=['louvain'],
    node_color='type',
    start_layout=5,
    edge_size=lambda u, v: g.degree(u) + g.degree(v),
    edge_size_range=(0.5, 5),
    label_font='cursive',
    node_label_size=g.degree,
    label_density=0
)
# Out:
# Sigma(nx.Graph with 158 nodes and 279 edges)

# %%
#  Option YFiles: the graph is out there...
# from yfiles_jupyter_graphs import GraphWidget
# 
# w = GraphWidget(graph=g)
# w.set_sidebar(enabled=False)
# 
# display(w)

# %% [markdown]
# ## Explore the RML

# %%
rmlts = pyoxigraph.Store()
mime_type = "application/x-turtle"  # application/n-triples or application/n-quads if you are loading those from data raw
rml1 = "./RML/attribute_template.ttl"
rml2 = "./RML/gdsc_template.ttl"
rml3 = "./RML/geo_template.ttl"

rmlts.bulk_load(rml1, mime_type, base_iri=None, to_graph=None)
# rmlts.bulk_load(rml2, mime_type, base_iri=None, to_graph=None)
rmlts.bulk_load(rml3, mime_type, base_iri=None, to_graph=None)

# %%
rmlquery = """	PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <https://schema.org/>
PREFIX rml: <http://w3id.org/rml/>
PREFIX sd: <https://w3id.org/okn/o/sd#>
PREFIX insta: <http://instagram.com/data/>
PREFIX rr: <http://www.w3.org/ns/r2rml#>

SELECT DISTINCT ?tm ?pred ?template
WHERE {
{
    # ?tm a rml:TriplesMap .
    BIND (rml:subjectMap AS ?pred) .
    # ?tm ?pred ?sm .
    # ?sm rml:template ?template .
    }
    UNION {
    # ?tm a rml:TriplesMap .
    # ?tm rml:predicateObjectMap ?po .
    # ?po rml:predicateMap ?pm .
    BIND (rml:constant AS ?pred) .
    # ?pm ?pred ?template .

    }
}
"""

q3 = list(rmlts.query(rmlquery))
dfrml = pd.DataFrame(q3)
dfrml.rename(columns={0: 'tm', 1: 'sm'}, inplace=True)

# %%
dfrml
# Out:
#                                                tm  \
# 0   <https://example.org/DatasetMapping/Variable>
# 1   <https://example.org/DatasetMapping/Variable>
# 2   <https://example.org/DatasetMapping/Variable>
# 3   <https://example.org/DatasetMapping/Variable>
# 4   <https://example.org/DatasetMapping/Variable>
# 5   <https://example.org/DatasetMapping/Variable>
# 6   <https://example.org/DatasetMapping/Variable>
# 7   <https://example.org/DatasetMapping/Variable>
# 8   <https://example.org/DatasetMapping/Variable>
# 9   <https://example.org/DatasetMapping/Variable>
# 10  <https://example.org/DatasetMapping/Variable>
# 11           <https://example.org/DatasetMapping>
# 12           <https://example.org/DatasetMapping>
# 13      <https://example.org/GeoMapping/Polygon1>
# 14      <https://example.org/GeoMapping/Polygon1>
# 15      <https://example.org/GeoMapping/Geometry>
# 16  <https://example.org/DatasetMapping/Variable>
# 17           <https://example.org/DatasetMapping>
# 18      <https://example.org/GeoMapping/Polygon1>
# 19      <https://example.org/GeoMapping/Geometry>
#
#                                   sm  \
# 0     <http://w3id.org/rml/constant>
# 1     <http://w3id.org/rml/constant>
# 2     <http://w3id.org/rml/constant>
# 3     <http://w3id.org/rml/constant>
# 4     <http://w3id.org/rml/constant>
# 5     <http://w3id.org/rml/constant>
# 6     <http://w3id.org/rml/constant>
# 7     <http://w3id.org/rml/constant>
# 8     <http://w3id.org/rml/constant>
# 9     <http://w3id.org/rml/constant>
# 10    <http://w3id.org/rml/constant>
# 11    <http://w3id.org/rml/constant>
# 12    <http://w3id.org/rml/constant>
# 13    <http://w3id.org/rml/constant>
# 14    <http://w3id.org/rml/constant>
# 15    <http://w3id.org/rml/constant>
# 16  <http://w3id.org/rml/subjectMap>
# 17  <http://w3id.org/rml/subjectMap>
# 18  <http://w3id.org/rml/subjectMap>
# 19  <http://w3id.org/rml/subjectMap>
#
#                                                     2
# 0                           <https://schema.org/name>
# 1              <https://schema.org/measurementMethod>
# 2                    <https://schema.org/description>
# 3                        <https://schema.org/endDate>
# 4                 <https://schema.org/unitsConceptId>
# 5                      <https://schema.org/startDate>
# 6                      <https://schema.org/conceptId>
# 7   <http://www.w3.org/1999/02/22-rdf-syntax-ns#type>
# 8                 <https://schema.org/additionalType>
# 9                         <https://schema.org/gaiaId>
# 10                     <https://schema.org/unitsText>
# 11  <http://www.w3.org/1999/02/22-rdf-syntax-ns#type>
# 12              <https://schema.org/variableMeasured>
# 13       <http://www.opengis.net/ont/geosparql#asWKT>
# 14  <http://www.w3.org/1999/02/22-rdf-syntax-ns#type>
# 15  <http://www.opengis.net/ont/geosparql#hasGeome...
# 16  "https://ohdsi_gis.org/.well-known/genid/{hash...
# 17                 "http://ohdsi_gis.org/id/{hashid}"
# 18  "https://ohdsi_gis.org/.well-known/genid/geo/{...
# 19                 "http://ohdsi_gis.org/id/{hashid}"
